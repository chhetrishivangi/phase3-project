# %% [markdown]
# # Zomato Restaurant Project

# %% [markdown]
# Project Description
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
# Country_code.csv contains two variables:
#
# • Country code
# • Country name
#
# Problem statement : In this dataset predict 2 things –
#
# 1) Average Cost for two
# 2) Price range

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os
import scipy as stats
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("zomato.csv")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# # In the above dataset there is total 9551 rows and  21 columns present.
#
# In the dataset it contains the details of the zomato restaurant along with the Restaurant details.
#
# The dataset contains both categorical and numerical columns.
#
# In the dataset the Average Cost for two and Price range column is our target variable.
#
# In the dataset we need to predict 2 things –
#
# 1) Average Cost for two
#
# 2) Price range

# %%
df2=pd.read_excel('Country-Code.xlsx')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# These are the country name with the country code

# %%
df =pd.merge(df1,df2,on='Country Code',how='left')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# In the above dataset we have merged both of the dataset and after creating a single dataset now we have 9551 rows and 22 columns

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# It helps in checking the dimension of dataset.
#
# The above dataset contains 9551 rows and 22 columns including the target column

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# This method shows the top 5 columns of the dataset

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %% [markdown]
# This method shows the bottom 5 columns of the dataset

# %%
df.sample(5)
# Out:
#       Restaurant ID                Restaurant Name  Country Code       City  \
# 1653         308726  Shree Bikaner Misthan Bhandar             1    Gurgaon
# 2946       18373691                  Dogs & Wiches             1  New Delhi
# 8970       18418649                Swag Sadda Desi             1      Noida
# 2036           1920                         Gopala             1    Gurgaon
# 2887       18466395       Annapurna Chaat & Sweets             1  New Delhi
#
#                                                 Address  \
# 1653  Opposite B & C Block Gate, Near Spanish Court,...
# 2946  Shop 105, 1st Floor, Chittaranjan Park, New Delhi
# 8970  Amrapali Zodiac Market, Sector 120, Near Secto...
# 2036  D-85, Shopping Mall, Arjun Marg, DLF Phase 1, ...
# 2887  Near Sheeshganj Gurudwara, Chandni Chowk, New ...
#
#                         Locality                     Locality Verbose  \
# 1653                 Palam Vihar                 Palam Vihar, Gurgaon
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# In the above method it shows the name of different columns

# %%
df.columns.tolist()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes',
#  'Country']

# %% [markdown]
# Converting the columns into the list format

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# The above dataset contains the integer,float and oject datatype columns.
#
# The dtype of the dataset is object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# It helps to get the good overview of the dataset.
#
# The dataset contains 9551 rows and 21 columns.
#
# In the dataset there is some null values present in Cuisines columns
#
# The dataset consist of object,float and integer datatype.
#
# The total memory usage of the dataset is 1.7+ MB

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# In the above dataset there is 9 null values present in Cuisines columns.

# %%
missing_values= pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing_values)
plt.xticks(rotation =90,fontsize =13)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# In the above plot we clearly see missing values present in the dataset and it is in Cuisines Columns only.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
nan_values = df.isna()
nan_columns = nan_values.any()

columns_with_nan = df.columns[nan_columns].tolist()
print(columns_with_nan)
# Out:
# ['Cuisines']

# %%
print(df['Cuisines'].unique())
# Out:
# ['French, Japanese, Desserts' 'Japanese'
#  'Seafood, Asian, Filipino, Indian' ... 'Burger, Izgara'
#  'World Cuisine, Patisserie, Cafe' 'Italian, World Cuisine']

# %%
df['Cuisines']=df['Cuisines'].fillna("No Cuisines")

# %%
len(df[df['Cuisines']=='No Cuisines'])
# Out:
# 9

# %%
missing_values = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(10,8))
ax = sns.pointplot('index',0,data=missing_values)
plt.xticks(rotation =90,fontsize =8)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
for i in df.columns:
        print(df[i].value_counts())
        print("\n")
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# ...

# %% [markdown]
# In the above column checking the value counts of each columns

# %%
df[df.columns[(df == '?').any()]].nunique()
# Out:
# Series([], dtype: float64)

# %%
df.drop("Address",axis=1,inplace=True)

# %%
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1826
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# This method shows the number of unique values present in each column of the dataset.

# %%
df.drop("Restaurant ID",axis=1,inplace=True)

# %% [markdown]
# In the above dataset the column Restaurant ID have 9551 unique values which means they have only one value count.
#
# So it not required for the prediction so we can drop the above column from our dataset

# %%
category_column=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        category_column.append(i)
print(category_column)
# Out:
# ['Restaurant Name', 'City', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text', 'Country']

# %% [markdown]
# It helps in checking the categorical columns in the dataset.
#
# These are the categorical columns present in the dataset.

# %%
numerical_column=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_column.append(i)
print(numerical_column)
# Out:
# ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %% [markdown]
# In the above dataset these are the numerical columns present.

# %%
df.loc[df["Country"]==" "]
# Out:
# Empty DataFrame
# Columns: [Restaurant Name, Country Code, City, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []

# %% [markdown]
# In the above dataset there is no spaces present

# %%
df2 = df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df2
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
df['Aggregate rating'].unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 0. , 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.9, 2.4, 2.6, 2.8,
#        2.1, 2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %%
df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %% [markdown]
# In the above data can see that it is regression problem

# %%
df.loc[df['Average Cost for two']==" "]
# Out:
# Empty DataFrame
# Columns: [Restaurant Name, Country Code, City, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []

# %% [markdown]
# There are no space in the target variable

# %%
No_rating = df[df['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
No_rating
# Out:
#           Country  Rating Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %%
Max_rating = df[df['Rating color']=='Dark Green'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
Max_rating
# Out:
#            Country  Rating Count
# 0        Australia             1
# 1           Brazil            16
# 2            India           116
# 3        Indonesia             7
# 4      New Zealand            12
# 5      Phillipines            12
# 6            Qatar             4
# 7     South Africa            12
# 8        Sri Lanka             2
# 9           Turkey            10
# 10             UAE            18
# 11  United Kingdom            23
# 12   United States            68

# %% [markdown]
# In the above dataset India seems to have maximum unrated restaurants.
#
# This may be because India has the maximum restuarants listed on Zomato from all over the world.

# %%
country_currency = df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index(name='count').drop('count', axis=1, inplace=False)
country_currency.sort_values('Currency').reset_index(drop=True)
# Out:
#            Country                Currency
# 0      Phillipines        Botswana Pula(P)
# 1           Brazil      Brazilian Real(R$)
# 2        Australia               Dollar($)
# 3           Canada               Dollar($)
# 4        Singapore               Dollar($)
# 5    United States               Dollar($)
# 6              UAE      Emirati Diram(AED)
# 7            India      Indian Rupees(Rs.)
# 8        Indonesia  Indonesian Rupiah(IDR)
# 9      New Zealand           NewZealand($)
# 10  United Kingdom              Pounds(��)
# 11           Qatar         Qatari Rial(QR)
# 12    South Africa                 Rand(R)
# 13       Sri Lanka   Sri Lankan Rupee(LKR)
# 14          Turkey        Turkish Lira(TL)

# %%
df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# We see that country India is has the maximum counts in all the dataset

# %%
indiaRes=df[df['Country']=='India']
singaporeRes=df[df['Country']=='Singapore']
AusRes=df[df['Country']=='Australia']
BrazRes=df[df['Country']=='Brazil']
CanadaRes=df[df['Country']=='Canada']
UAERes=df[df['Country']=='UAE']
UKRes=df[df['Country']=='United Kingdom']
USRes=df[df['Country']=='United States']
SouthAfricaRes=df[df['Country']=='South Africa']
NewZelandRes=df[df['Country']=='New Zealand']
TurkeyRes=df[df['Country']=='Turkey']
IndonesiaRes=df[df['Country']=='Indonesia']
QatarRes=df[df['Country']=='Qatar']
SrilankaRes=df[df['Country']=='Sri Lanka']

# %%
indiaRes.head()
# Out:
#                            Restaurant Name  Country Code  City     Locality  \
# 624                             Jahanpanah             1  Agra   Agra Cantt
# 625                    Rangrezz Restaurant             1  Agra   Agra Cantt
# 626                Time2Eat - Mama Chicken             1  Agra   Agra Cantt
# 627  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra  Civil Lines
# 628                         Pinch Of Spice             1  Agra  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# 624   Agra Cantt, Agra  78.011544  27.161661           North Indian, Mughlai
# 625   Agra Cantt, Agra   0.000000   0.000000           North Indian, Mughlai
# 626   Agra Cantt, Agra  78.011608  27.160832                    North Indian
# 627  Civil Lines, Agra  77.998092  27.195928                      Rajasthani
# 628  Civil Lines, Agra  78.007553  27.201725  North Indian, Chinese, Mughlai
#
# ...

# %% [markdown]
# In the above data this is the name of the different restaurant name in country India

# %%
indiaRes.City.value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
plt.figure(figsize=(8,10))
sns.countplot(indiaRes['City'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# In the above plot Delhi has the highest Count of Restaurant in India and the least is Mohali.

# %%
DelhiTopRes=indiaRes[(indiaRes['City']=='New Delhi')&(indiaRes['Aggregate rating']>4.5)][['Aggregate rating','Restaurant Name','Votes']].sort_values(ascending=False,by='Votes')

# %%
DelhiTopRes
# Out:
#       Aggregate rating            Restaurant Name  Votes
# 3013               4.9         Naturals Ice Cream   2620
# 3601               4.9  Indian Accent - The Manor   1934
# 6659               4.6   The California Boulevard   1691
# 4639               4.6                  Big Chill   1569
# 6997               4.7        Echoes Satyaniketan   1563
# 7849               4.6            Cafeteria & Co.   1136
# 3310               4.6              Spezia Bistro   1071
# 6657               4.7         Naturals Ice Cream    474
# 4298               4.9             Masala Library    408
# 3732               4.6                     Tashan    304
# 7067               4.7                   Pa Pa Ya    268
# 3014               4.7   Zabardast Indian Kitchen    242
# 6655               4.6         Band Baaja Baaraat    128
# 7180               4.6                Greenr Cafe    112
# 6656               4.8               Kopper Kadai     83
# ...

# %%
plt.figure(figsize=(8,10))
sns.countplot(DelhiTopRes['Restaurant Name'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# In the above plot Naturals Ice creams has the highest rating and Votes as compared to others in Delhi

# %%
DelhiTopResOnline=indiaRes[(indiaRes['City']=='New Delhi')&(indiaRes['Aggregate rating']>4.5) &(indiaRes['Has Online delivery']=='Yes')][['Aggregate rating','Restaurant Name','Votes','Has Online delivery']].sort_values(ascending=False,by='Votes')

# %%
DelhiTopResOnline
# Out:
#       Aggregate rating           Restaurant Name  Votes Has Online delivery
# 3013               4.9        Naturals Ice Cream   2620                 Yes
# 3310               4.6             Spezia Bistro   1071                 Yes
# 6657               4.7        Naturals Ice Cream    474                 Yes
# 3014               4.7  Zabardast Indian Kitchen    242                 Yes
# 7180               4.6               Greenr Cafe    112                 Yes
# 6426               4.6               Food Scouts     61                 Yes

# %%
plt.figure(figsize=(8,10))
sns.factorplot('Restaurant Name',kind='count',data=DelhiTopResOnline,hue='Has Online delivery',palette="dark")
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot('Votes','Aggregate rating',data=DelhiTopRes)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Aggregate rating'>

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# In the above data the value count of the target column Price range.
#
# Further we notice there is huge difference in different category, which means our target column is imbalanced

# %%
plt.figure(figsize=(8,10))
sns.countplot(df['Price range'])
plt.xticks(rotation=90)
plt.show()

# %%
def generate_pie(i):
    plt.figure(figsize=(10,8))
    plt.pie(i.value_counts(), labels=i.value_counts().index, autopct='%1.2f%%',shadow=True,)
    plt.legend(prop={'size':13})
    plt.axis('equal')
    plt.tight_layout()
    return plt.show()

# %%
columns=['Has Table booking', 'Has Online delivery', 'Is delivering now','Price range', 'Rating color','Rating text']

# %%
plotnumber=1
for j in df[columns]:
    print(f"Pie plot for the column:", j)
    generate_pie(df[j])
# Out:
# Pie plot for the column: Has Table booking
# Pie plot for the column: Has Online delivery
# Pie plot for the column: Is delivering now
# Pie plot for the column: Price range
# Pie plot for the column: Rating color
# Pie plot for the column: Rating text

# %%
IndianCuisines=df[df['Country']=='India']['Cuisines'].value_counts().head()
IndianCuisines
# Out:
# North Indian             936
# North Indian, Chinese    511
# Fast Food                348
# Chinese                  340
# North Indian, Mughlai    334
# Name: Cuisines, dtype: int64

# %%
plt.figure(figsize=(8,10))
indiaRes['Cuisines'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Cuisines'>

# %%
df.head()
# Out:
#           Restaurant Name  Country Code              City  \
# 0        Le Petit Souffle           162       Makati City
# 1        Izakaya Kikufuji           162       Makati City
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                    Ooma           162  Mandaluyong City
# 4             Sambo Kojin           162  Mandaluyong City
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# ...

# %%
plt.figure(figsize=(25,35),facecolor='white')
plotnumber=1
for column in numerical_column:
    if plotnumber<=25:
        ax=plt.subplot(6,5,plotnumber)
        sns.distplot(df[column],color="red")
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# In the above plot we see that the Skewness is present in the dataset

# %%
rating_price= df.groupby('Price range').mean()['Aggregate rating'].sort_values(ascending=True)
print(rating_price)
# Out:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %%
(rating_price).plot(kind='line', xlabel='Price range', ylabel='Average of ratings', title='Average rating v/s Price range')
# Out:
# <AxesSubplot:title={'center':'Average rating v/s Price range'}, xlabel='Price range', ylabel='Average of ratings'>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(indiaRes["Rating text"],indiaRes["Average Cost for two"])
plt.show()

# %%
print(df['Rating text'].unique())
# Out:
# ['Excellent' 'Very Good' 'Good' 'Average' 'Not rated' 'Poor']

# %%
print(df['Rating text'].nunique())
# Out:
# 6

# %%
print(df['Rating text'].value_counts())
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df["Rating text"])
plt.show()

# %% [markdown]
# In the above plot we see that the maximum rating text is Average and the least is poor.

# %%
Restaraunts= (df.loc[df['Aggregate rating'] > 4.5, 'Restaurant Name'])
print(Restaraunts)
# Out:
# 0                               Le Petit Souffle
# 3                                           Ooma
# 4                                    Sambo Kojin
# 8       Spiral - Sofitel Philippine Plaza Manila
# 9                                       Locavore
#                           ...
# 9536                             Pizza ��l Forno
# 9537                         J'adore Chocolatier
# 9538                                   Starbucks
# 9540                            Draft Gastro Pub
# 9544                       Karak�_y G�_ll�_o��lu
# Name: Restaurant Name, Length: 206, dtype: object

# %%
((Restaraunts.value_counts()).head(10)).plot(kind='barh', color='red', figsize=(8,8))
plt.ylabel("Restaurants")
plt.title("Top 10 High Rated restaurant ")
plt.show()

# %% [markdown]
# In the above plot we can see that the Barbeque Nation is the Max rated restaraunts in Top 10

# %%
df.groupby('Restaurant Name').mean()['Votes'].sort_values(ascending=False)
# Out:
# Restaurant Name
# Toit                               10934.0
# Hauz Khas Social                    7931.0
# Peter Cat                           7574.0
# Big Brewsky                         5705.0
# The Black Pearl                     5385.0
#                                     ...
# New Bhappe Di Hatti                    0.0
# New Aggarwal Sweets & Fast Food        0.0
# Nehra's Food Point                     0.0
# Negi Restaurant                        0.0
# Laxmi Food Corner                      0.0
# Name: Votes, Length: 7446, dtype: float64

# %%
df.groupby('Restaurant Name').mean()['Votes'].sort_values(ascending=False)[:10].plot(kind='bar', color='blue', figsize=(8,6), title="Outlets Having Maximum Votes", xlabel='Top 10 Outlets', ylabel='Average votes')
# Out:
# <AxesSubplot:title={'center':'Outlets Having Maximum Votes'}, xlabel='Top 10 Outlets', ylabel='Average votes'>

# %% [markdown]
# In the above plot votes for Toits has the maximum votes as compared to others

# %%
df.plot(kind='box',subplots=True,layout=(10,8),figsize=(20,20),color='red')
# Out:
# Country Code              AxesSubplot(0.125,0.816017;0.0824468x0.0639831)
# Longitude               AxesSubplot(0.223936,0.816017;0.0824468x0.0639...
# Latitude                AxesSubplot(0.322872,0.816017;0.0824468x0.0639...
# Average Cost for two    AxesSubplot(0.421809,0.816017;0.0824468x0.0639...
# Price range             AxesSubplot(0.520745,0.816017;0.0824468x0.0639...
# Aggregate rating        AxesSubplot(0.619681,0.816017;0.0824468x0.0639...
# Votes                   AxesSubplot(0.718617,0.816017;0.0824468x0.0639...
# dtype: object

# %%
df.nunique()
# Out:
# Restaurant Name         7446
# Country Code              15
# City                     141
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1826
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
df.drop("Switch to order menu",axis=1,inplace=True)

df.drop("Restaurant Name",axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=LE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       Country Code  City  Locality  Locality Verbose   Longitude   Latitude  \
# 0              162    73       171               172  121.027535  14.565443
# 1              162    73       593               601  121.014101  14.553708
# 2              162    75       308               314  121.056831  14.581404
# 3              162    75       862               875  121.056475  14.585318
# 4              162    75       862               875  121.057508  14.584450
# ...            ...   ...       ...               ...         ...        ...
# 9546           208   140       517               523   28.977392  41.022793
# 9547           208   140       552               558   29.041297  41.009847
# 9548           208   140       554               561   29.034640  41.055817
# 9549           208   140       554               561   29.036019  41.057979
# 9550           208   140       670               681   29.026016  40.984776
#
# ...

# %%
df.corr()
# Out:
#                       Country Code      City  Locality  Locality Verbose  \
# Country Code              1.000000 -0.181728 -0.120076         -0.117543
# City                     -0.181728  1.000000  0.096443          0.093141
# Locality                 -0.120076  0.096443  1.000000          0.999465
# Locality Verbose         -0.117543  0.093141  0.999465          1.000000
# Longitude                -0.698299  0.117391  0.086446          0.084340
# Latitude                  0.019792 -0.004301 -0.020428         -0.020909
# Cuisines                 -0.132983  0.026632  0.007019          0.005986
# Average Cost for two      0.043225 -0.028838 -0.012136         -0.011852
# Currency                 -0.033466 -0.071996  0.023718          0.022960
# Has Table booking        -0.061682 -0.003762 -0.065594         -0.065132
# Has Online delivery      -0.154605  0.012723 -0.030993         -0.031766
# Is delivering now        -0.018291 -0.014039 -0.007299         -0.007353
# ...

# %%
plt.figure(figsize=(40,35))
sns.heatmap(df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':15},cmap="YlGnBu")
plt.yticks(rotation=0);

# %% [markdown]
# This heatmap shows the correlation matrix by visualizing the data. The above heat map contains both positive and negative correlation.

# %%
df.corr()['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.075083
# Votes                   0.067783
# Aggregate rating        0.051792
# Longitude               0.045891
# Currency                0.045615
# Country Code            0.043225
# Rating text             0.031439
# Has Table booking       0.007758
# Cuisines                0.005819
# Is delivering now      -0.001862
# Country                -0.004034
# Locality Verbose       -0.011852
# Locality               -0.012136
# Has Online delivery    -0.018974
# City                   -0.028838
# Rating color           -0.049970
# Latitude               -0.111088
# Name: Average Cost for two, dtype: float64

# %% [markdown]
# In the above data the positive and negative correlation is present between the features and the target.

# %%
plt.figure(figsize=(30,20))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='y')
plt.xlabel('Feature',fontsize=25)
plt.ylabel('target',fontsize=25)
plt.title('correlation between label and feature using bar plot',fontsize=25)
plt.show()

# %% [markdown]
# The columns Is delivering now and Country are very less correlated with the target.

# %%
df.drop("Is delivering now",axis=1,inplace=True)
df.drop("Country",axis=1,inplace=True)

# %% [markdown]
# After dropping the irrelevant columns

# %%
df.describe()
# Out:
#        Country Code         City     Locality  Locality Verbose    Longitude  \
# count   9551.000000  9551.000000  9551.000000       9551.000000  9551.000000
# mean      18.365616    78.301434   658.128678        677.305204    64.126574
# std       56.750546    23.198915   315.866877        331.727817    41.467058
# min        1.000000     0.000000     0.000000          0.000000  -157.948486
# 25%        1.000000    76.000000   381.000000        387.000000    77.081343
# 50%        1.000000    88.000000   696.000000        707.000000    77.191964
# 75%        1.000000    88.000000   921.000000        953.000000    77.282006
# max      216.000000   140.000000  1207.000000       1264.000000   174.832089
#
#           Latitude     Cuisines  Average Cost for two     Currency  \
# count  9551.000000  9551.000000           9551.000000  9551.000000
# mean     25.854381   989.883363           1199.210763     3.977699
# std      11.007935   514.573865          16121.183073     0.914242
# ...

# %% [markdown]
# It shows the statistical summary of dataset.
#
# The summary of this dataset looks perfect since there is no missing values present.
#
# The counts of all the columns are same.
#
# There is a huge difference between 75% and max which means the outliers are present in the columns.

# %%
plt.figure(figsize=(35,30))
sns.heatmap(df.describe(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':15},cmap="YlGnBu")
plt.yticks(rotation=0);

# %%
df.shape
# Out:
# (9551, 16)

# %% [markdown]
# In the above plot we are determine mean,standard deviation,minimum and maximum value of each column

# %%
df.skew()
# Out:
# Country Code             3.043965
# City                    -1.193777
# Locality                -0.253550
# Locality Verbose        -0.183059
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.306743
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %%
plt.rcParams['figure.figsize']=(25,20)
df.hist(bins=25,color='red',density=True,label='Value',histtype='bar')
plt.show()

# %% [markdown]
# In the above plot Country Code,Longitude,Latitude ,Average Cost for two,Price range,Aggregate rating and Votes have Skewness present.

# %%
df.columns
# Out:
# Index(['Country Code', 'City', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
outliers = df[['Country Code','Longitude','Latitude','Average Cost for two','Price range','Aggregate rating','Votes']]

# %%
from scipy.stats import zscore
zscore=np.abs(zscore(outliers))
zscore
# Out:
#       Country Code  Longitude  Latitude  Average Cost for two  Price range  \
# 0         2.531111   1.372269  1.025581              0.006154     1.319803
# 1         2.531111   1.371945  1.026647              0.000049     1.319803
# 2         2.531111   1.372975  1.024131              0.173743     2.424090
# 3         2.531111   1.372966  1.023775              0.018659     2.424090
# 4         2.531111   1.372991  1.023854              0.018659     2.424090
# ...            ...        ...       ...                   ...          ...
# 9546      3.341718   0.847685  1.378025              0.069428     1.319803
# 9547      3.341718   0.846144  1.376849              0.067878     1.319803
# 9548      3.341718   0.846305  1.381025              0.063845     2.424090
# 9549      3.341718   0.846272  1.381221              0.066947     2.424090
# 9550      3.341718   0.846513  1.374571              0.070979     0.215516
#
#       Aggregate rating     Votes
# 0             1.407131  0.365202
# ...

# %%
new_dataframe = df[(zscore<3).all(axis=1)] 
new_dataframe
# Out:
#       Country Code  City  Locality  Locality Verbose   Longitude   Latitude  \
# 0              162    73       171               172  121.027535  14.565443
# 1              162    73       593               601  121.014101  14.553708
# 2              162    75       308               314  121.056831  14.581404
# 3              162    75       862               875  121.056475  14.585318
# 4              162    75       862               875  121.057508  14.584450
# ...            ...   ...       ...               ...         ...        ...
# 9432           166    38      1063              1116   51.526653  25.323261
# 9433           166    38      1086              1139   51.530127  25.350325
# 9434           166    38      1092              1145   51.512909  25.276180
# 9435           166    38      1115              1170   51.544576  25.273020
# 9436           166    38      1115              1170   51.546714  25.283011
#
# ...

# %% [markdown]
# After removing the outliers we are getting 8565 rows and 16 columns in the new dataset

# %%
df.shape
# Out:
# (9551, 16)

# %% [markdown]
# This is the shape of original dataset. Before removing the outliers we had 9551 rows and 16 columns in our dataset.

# %%
new_dataframe.shape
# Out:
# (8565, 16)

# %% [markdown]
# This is the shape of the new dataset. After removing the outliers we having 8565 rows and 16 columns in our new dataset.

# %%
Lost_data = (9551-8565)/9551*100
Lost_data
# Out:
# 10.323526332321222

# %% [markdown]
# Through zscore method we are losing 10.32% of the data from our dataset

# %%
Q1=outliers.quantile(0.25)

Q3=outliers.quantile(0.75)

IQR=Q3-Q1

dataset=df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
dataset.shape
# Out:
# (4704, 16)

# %% [markdown]
# Through IQR method the dataframe has 4704 rows and 16 columns.

# %%
loss_data = (9551-4704)/9551*100
loss_data
# Out:
# 50.748612710710916

# %% [markdown]
# Using IQR method we are losing 50.74% of the data

# %%
skewness=['Country Code','Longitude','Latitude' ,'Average Cost for two','Price range','Aggregate rating','Votes']

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
new_dataframe[skewness] = scaler.fit_transform(new_dataframe[skewness].values)
new_dataframe[skewness].head()
# Out:
#    Country Code  Longitude  Latitude  Average Cost for two  Price range  \
# 0     11.616899   7.096817 -2.870154              1.170136     1.385129
# 1     11.616899   7.094048 -2.870996              1.291498     1.385129
# 2     11.616899   7.102859 -2.869007              3.044151     1.744844
# 3     11.616899   7.102785 -2.868725              1.605942     1.744844
# 4     11.616899   7.102998 -2.868788              1.605942     1.744844
#
#    Aggregate rating     Votes
# 0          1.972392  1.410787
# 1          1.649065  1.753948
# 2          1.543945  1.329422
# 3          2.082799  1.492117
# 4          1.972392  1.240914

# %%
new_dataframe[skewness].skew()
# Out:
# Country Code            11.532839
# Longitude               -0.249360
# Latitude                -2.531937
# Average Cost for two     0.044229
# Price range              0.240185
# Aggregate rating        -0.631024
# Votes                   -0.008984
# dtype: float64

# %%
plt.figure(figsize=(12,12), facecolor='white')
plotnumber = 1

for column in new_dataframe[skewness]:
    if plotnumber<=10:
        ax = plt.subplot(2,7,plotnumber)
        sns.distplot(df[column],color="red")
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
new_dataframe.head()
# Out:
#    Country Code  City  Locality  Locality Verbose  Longitude  Latitude  \
# 0     11.616899    73       171               172   7.096817 -2.870154
# 1     11.616899    73       593               601   7.094048 -2.870996
# 2     11.616899    75       308               314   7.102859 -2.869007
# 3     11.616899    75       862               875   7.102785 -2.868725
# 4     11.616899    75       862               875   7.102998 -2.868788
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0       920              1.170136         0                  1
# 1      1111              1.291498         0                  1
# 2      1672              3.044151         0                  1
# 3      1126              1.605942         0                  0
# 4      1122              1.605942         0                  1
#
#    Has Online delivery  Price range  Aggregate rating  Rating color  \
# 0                    0     1.385129          1.972392             0
# ...

# %%
x= new_dataframe.drop("Average Cost for two",axis=1)

y= new_dataframe["Average Cost for two"]

# %%
x.shape
# Out:
# (8565, 15)

# %%
y.shape
# Out:
# (8565,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head()
# Out:
#    Country Code      City  Locality  Locality Verbose  Longitude  Latitude  \
# 0     11.616901 -0.350524 -1.639342         -1.617142   7.096817 -2.870154
# 1     11.616901 -0.350524 -0.261938         -0.285302   7.094048 -2.870996
# 2     11.616901 -0.246545 -1.192175         -1.176300   7.102859 -2.869007
# 3     11.616901 -0.246545  0.616075          0.565336   7.102785 -2.868725
# 4     11.616901 -0.246545  0.616075          0.565336   7.102998 -2.868788
#
#    Cuisines   Currency  Has Table booking  Has Online delivery  Price range  \
# 0 -0.182932 -13.447769           2.652303            -0.617978     1.385129
# 1  0.196620 -13.447769           2.652303            -0.617978     1.385129
# 2  1.311428 -13.447769           2.652303            -0.617978     1.744844
# 3  0.226428 -13.447769          -0.377031            -0.617978     1.744844
# 4  0.218479 -13.447769           2.652303            -0.617978     1.744844
#
#    Aggregate rating  Rating color  Rating text     Votes
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values             Features
# 0     1.461026         Country Code
# 1     1.078664                 City
# 2   886.414838             Locality
# 3   886.135223     Locality Verbose
# 4     3.080093            Longitude
# 5     2.787892             Latitude
# 6     1.025043             Cuisines
# 7     1.503753             Currency
# 8     1.395456    Has Table booking
# 9     1.230983  Has Online delivery
# 10    1.758696          Price range
# 11    4.708945     Aggregate rating
# 12    1.239534         Rating color
# 13    1.305338          Rating text
# 14    5.042861                Votes

# %% [markdown]
# We can observe some columns have VIF above 10 that means they are causing multicollinearity problem.

# %%
x.drop(["Locality"],axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(x.values, i) 
                     for i in range(x.shape[1])]
vif["Features"]=x.columns

vif
# Out:
#     vif_Features             Features
# 0       1.460309         Country Code
# 1       1.072068                 City
# 2       1.039195     Locality Verbose
# 3       3.078911            Longitude
# 4       2.787356             Latitude
# 5       1.024337             Cuisines
# 6       1.503571             Currency
# 7       1.395387    Has Table booking
# 8       1.229997  Has Online delivery
# 9       1.756796          Price range
# 10      4.708015     Aggregate rating
# 11      1.239424         Rating color
# 12      1.304927          Rating text
# 13      5.039398                Votes

# %% [markdown]
# Now the above dataset is free from multicollinearity

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)    
    pred_test=lr.predict(x_test)
    print('The r2 score is:', r2_score(y_test, pred_test))
    print('The mean absolute error', mean_absolute_error(y_test, pred_test))
    print('The mean squared error', mean_squared_error(y_test, pred_test))
# Out:
# The r2 score is: 0.7448875254445875
# The mean absolute error 0.3616192784679112
# The mean squared error 0.2457491868037913
# The r2 score is: 0.7491652451434667
# The mean absolute error 0.3618545327593116
# The mean squared error 0.23656823524685425
# The r2 score is: 0.7326480741467907
# The mean absolute error 0.37795427806360044
# The mean squared error 0.2722927919353788
# The r2 score is: 0.7275027582254111
# The mean absolute error 0.3625047782581101
# The mean squared error 0.26894605919783576
# The r2 score is: 0.7635025186565578
# The mean absolute error 0.3661422447678433
# The mean squared error 0.2334191469637636
# The r2 score is: 0.7533456818101057
# The mean absolute error 0.37798328457686775
# The mean squared error 0.2631116514313933
# The r2 score is: 0.7424310297195043
# The mean absolute error 0.36504174979800125
# The mean squared error 0.261992459192298
# The r2 score is: 0.7204269407544153
# The mean absolute error 0.3628374203241742
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=18)

# %%
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print('The r2 score is:', r2_score(y_test, pred_test))
print('The mean absolute error', mean_absolute_error(y_test, pred_test))
print('The mean squared error', mean_squared_error(y_test, pred_test))
# Out:
# The r2 score is: 0.737621705277812
# The mean absolute error 0.3654144940980526
# The mean squared error 0.24289582240299676

# %% [markdown]
# The accuracy score for Linear Regression is 73.76%

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
dt=r2_score(y_test,predDTR)
print('The r2 score is:', r2_score(y_test, predDTR))
print('The mean absolute error', mean_absolute_error(y_test, predDTR))
print('The mean squared error', mean_squared_error(y_test, predDTR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,predDTR)))
# Out:
# The r2 score is: 0.6518060075677549
# The mean absolute error 0.3575855252813116
# The mean squared error 0.3223394154503625
# root_mean_squared_error: 0.5677494301629571

# %% [markdown]
# The accuracy score for Decision Tree Regressor is 65.18%

# %%
knn = KNeighborsRegressor()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
print('The r2 score is:', r2_score(y_test, pred_knn))
print('The mean absolute error', mean_absolute_error(y_test, pred_knn))
print('The mean squared error', mean_squared_error(y_test, pred_knn))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# The r2 score is: 0.7317259807752223
# The mean absolute error 0.3545663353874226
# The mean squared error 0.24835376949894192
# root_mean_squared_error: 0.4983510504643709

# %% [markdown]
# The accuracy score for KNeighborsRegressor is 73.17%

# %%
rdf = RandomForestRegressor()
rdf.fit(x_train,y_train)
pred_rdf = rdf.predict(x_test)
print('The r2 score is:', r2_score(y_test, pred_rdf))
print('The mean absolute error', mean_absolute_error(y_test, pred_rdf))
print('The mean squared error', mean_squared_error(y_test, pred_rdf))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_rdf)))
# Out:
# The r2 score is: 0.8119419358613131
# The mean absolute error 0.28596595885037396
# The mean squared error 0.17409411932053026
# root_mean_squared_error: 0.4172458739406901

# %% [markdown]
# The accuracy score for Random Forest Regressor is 81.19%

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_gbr=GBR.predict(x_test)
print('R2_score:',r2_score(y_test,pred_gbr))
print('mean_squared_error:',mean_squared_error(y_test,pred_gbr))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_gbr))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# R2_score: 0.8249988050056439
# mean_squared_error: 0.16200676669794178
# mean_absolute_error: 0.2874899526034993
# root_mean_squared_error: 0.40250064186028545

# %% [markdown]
# The accuracy score for GradientBoostingRegressor is 82.49%

# %%
XT=ExtraTreesRegressor()
XT.fit(x_train,y_train)
predXT=XT.predict(x_test)
print('R2_Score:',r2_score(y_test,predXT))
print('MAE:',metrics.mean_absolute_error(y_test, predXT))
print('MSE:',metrics.mean_squared_error(y_test, predXT))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predXT)))
# Out:
# R2_Score: 0.8156403688657043
# MAE: 0.29613044889445295
# MSE: 0.17067030742650466
# RMSE: 0.41312263001015165

# %% [markdown]
# The accuracy score for ExtraTreesRegressor is 81.56%

# %%
from sklearn.model_selection import cross_val_score

# %%
print("lr crossvalidation score",cross_val_score(lr,x,y,cv=5).mean())
print("DTR crossvalidation score",cross_val_score(DTR,x,y,cv=5).mean())
print("rdf crossvalidationscore",cross_val_score(rdf,x,y,cv=5).mean())
print("knn crossvalidationscore",cross_val_score(knn,x,y,cv=5).mean())
print("GB crossvalidationscore",cross_val_score(GBR,x,y,cv=5).mean())
print("XTcrossvalidationscore",cross_val_score(XT,x,y,cv=5).mean())
# Out:
# lr crossvalidation score 0.43912805853609926
# DTR crossvalidation score -2.006197837563084
# rdf crossvalidationscore -0.3558223174700876
# knn crossvalidationscore 0.6408995207163206
# GB crossvalidationscore 0.02071949071062047
# XTcrossvalidationscore 0.6013173319328164

# %% [markdown]
# In the above data these are the cross validation scores for the different models.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=63)
Final_Accu = GradientBoostingRegressor()
Final_Accu.fit(x_train,y_train)
pred_gbr = Final_Accu.predict(x_test)
print('The r2 score is:', r2_score(y_test, pred_gbr))
print('The mean absolute error', mean_absolute_error(y_test, pred_gbr))
print('The mean squared error', mean_squared_error(y_test, pred_gbr))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# The r2 score is: 0.8223860735409044
# The mean absolute error 0.29640031844633313
# The mean squared error 0.18682809703369266
# root_mean_squared_error: 0.43223615886884414

# %% [markdown]
# The final accuracy score for the best fit model is 82.23%

# %%
import joblib
joblib.dump(Final_Accu,"Zomato_prediction.obj")
# Out:
# ['Zomato_prediction.obj']

# %%
Model=joblib.load("Zomato_prediction.obj")

# %%
predict=Model.predict(x_test)
predict
# Out:
# array([-0.60215625,  1.23972143,  1.43016992, ...,  0.39499168,
#         2.05776259, -0.49114439])
